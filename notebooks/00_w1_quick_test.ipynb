# %% [markdown]
# # Session 1 — Data Intro: Quick Test
#
# This notebook is a short **environment + fundamentals test** for Session 1.
#
# You will check that your Python environment works, inspect a small dataset, make a simple visualisation, and formulate a research question.

# %% [markdown]
# ## 1. Environment check
#
# Run the following cell. If it runs without errors, your main course packages are available.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(f"Python: {sys.version.split()[0]}")
print(f"NumPy: {np.__version__}")
print(f"pandas: {pd.__version__}")

print("\n✓ Environment check passed")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Python: 3.13.1
# NumPy: 2.5.3
# pandas: 3.0.5
#
# ✓ Environment check passed

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(f"Python: {sys.version.split()[0]}")
print(f"NumPy: {np.__version__}")
print(f"pandas: {pd.__version__}")

print("\n✓ Environment check passed")
# Out:
# Python: 3.13.1
# NumPy: 2.5.3
# pandas: 3.0.5
#
# ✓ Environment check passed

# %% [markdown]
# The dataset in `../data/abc.csv` represents a small fictional study of university students. Each row is one student.
#
# **Variables:**
# - `student_id` — identifier
# - `study_hours` — average hours studied per week
# - `sleep_hours` — average hours of sleep per night
# - `stress` — self-reported stress score from 1–10
# - `course` — broad course group
# - `passed` — whether the student passed the assessment

# %%
data = pd.read_csv("../data/abc.csv")

data.head()
# Out:
#    student_id  study_hours  sleep_hours  stress      course  passed
# 0           1            8          7.5       5  Psychology       1
# 1           2           12          6.5       7     Science       1
# 2           3            5          8.0       4  Psychology       0
# 3           4           15          6.0       8     Science       1
# 4           5           10          7.0       6  Psychology       1

# %% [markdown]
# ## ✓ Submission checklist
#
# Before submitting, make sure that:
#
# - [ ] All code cells run without errors.
#
# **Tip:** Save the notebook with your name/group identifier before submitting.
